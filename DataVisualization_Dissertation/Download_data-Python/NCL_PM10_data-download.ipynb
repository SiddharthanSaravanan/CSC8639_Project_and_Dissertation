# %%
# !pip install geojson
# Out:
# Requirement already satisfied: geojson in /usr/local/lib/python3.7/dist-packages (2.5.0)

# %%
import requests
import geojson
import pandas as pd
import io
import datetime

# %%
def func(start_time, end_time):
    date_format = "%Y%m%d%H%M%S"
    data_func = dict(
    data_variable= 'PM10',
    agg_method='mean',
    agg_period='1hour',
    starttime=start_time.strftime(date_format),
    endtime=end_time.strftime(date_format) 
    )
    return data_func

# %% [markdown]
# PM10 values of July 2019

# %%
start_time = datetime.datetime(2019,7,1,0)
end_time = datetime.datetime(2019,7,6)
jul_19_fun = func(start_time, end_time)
jul_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20190706000000',
#  'starttime': '20190701000000'}

# %%
jul_19_1 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',jul_19_fun)
jul_19_1
# Out:
# <Response [200]>

# %%
jul_2019_1 = pd.read_csv(io.StringIO(jul_19_1.text) )
jul_2019_1 = jul_2019_1[['Variable','Timestamp','Value','Location (WKT)']]
jul_2019_1
# Out:
#      Variable  ...                             Location (WKT)
# 0        PM10  ...                POINT (-1.619756 55.006886)
# 1        PM10  ...  POINT (-1.5762135386467 54.9843088529622)
# 2        PM10  ...                POINT (-1.590481 55.007634)
# 3        PM10  ...                POINT (-1.566521 55.011258)
# 4        PM10  ...                POINT (-1.593537 55.039309)
# ...       ...  ...                                        ...
# 5511     PM10  ...                POINT (-1.558721 54.996494)
# 5512     PM10  ...                POINT (-1.613355 54.977854)
# 5513     PM10  ...                POINT (-1.612715 54.975755)
# 5514     PM10  ...                   POINT (-1.6135 54.97768)
# 5515     PM10  ...                  POINT (-1.61014 54.97461)
#
# [5516 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,7,6,0)
end_time = datetime.datetime(2019,7,11)
jul_19_fun = func(start_time, end_time)
jul_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20190711000000',
#  'starttime': '20190706000000'}

# %%
jul_19_2 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',jul_19_fun)
jul_19_2
# Out:
# <Response [200]>

# %%
jul_2019_2 = pd.read_csv(io.StringIO(jul_19_2.text) )
jul_2019_2 = jul_2019_2[['Variable','Timestamp','Value','Location (WKT)']]
jul_2019_2
# Out:
#      Variable            Timestamp      Value               Location (WKT)
# 0        PM10  2019-07-06 00:00:00   1.773333  POINT (-1.619756 55.006886)
# 1        PM10  2019-07-06 00:00:00   2.683136  POINT (-1.550289 54.980095)
# 2        PM10  2019-07-06 00:00:00   5.049927   POINT (-1.577888 54.98891)
# 3        PM10  2019-07-06 00:00:00   4.138709  POINT (-1.553981 54.951477)
# 4        PM10  2019-07-06 00:00:00   0.375593  POINT (-1.690413 54.957331)
# ...       ...                  ...        ...                          ...
# 5515     PM10  2019-07-10 23:00:00  10.310000  POINT (-1.612715 54.975755)
# 5516     PM10  2019-07-10 23:00:00   7.918000  POINT (-1.613355 54.977854)
# 5517     PM10  2019-07-10 23:00:00  11.640000  POINT (-1.558721 54.996494)
# 5518     PM10  2019-07-10 23:00:00   7.960000  POINT (-1.606514 54.973793)
# 5519     PM10  2019-07-10 23:00:00  13.558300  POINT (-1.603461 54.965666)
#
# [5520 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,7,11,0)
end_time = datetime.datetime(2019,7,16)
jul_19_fun = func(start_time, end_time)
jul_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20190716000000',
#  'starttime': '20190711000000'}

# %%
jul_19_3 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',jul_19_fun)
jul_19_3
# Out:
# <Response [200]>

# %%
jul_2019_3 = pd.read_csv(io.StringIO(jul_19_3.text) )
jul_2019_3 = jul_2019_3[['Variable','Timestamp','Value','Location (WKT)']]
jul_2019_3
# Out:
#      Variable  ...                             Location (WKT)
# 0        PM10  ...                POINT (-1.619756 55.006886)
# 1        PM10  ...                POINT (-1.718833 54.995352)
# 2        PM10  ...                POINT (-1.606514 54.973793)
# 3        PM10  ...  POINT (-1.5762135386467 54.9843088529622)
# 4        PM10  ...                POINT (-1.521943 55.029411)
# ...       ...  ...                                        ...
# 5591     PM10  ...                POINT (-1.594308 55.023115)
# 5592     PM10  ...                POINT (-1.611256 55.012987)
# 5593     PM10  ...                POINT (-1.617166 54.974211)
# 5594     PM10  ...        POINT (-1.210895 54.58024399999999)
# 5595     PM10  ...                POINT (-1.603448 54.965685)
#
# [5596 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,7,16,0)
end_time = datetime.datetime(2019,7,21)
jul_19_fun = func(start_time, end_time)
jul_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20190721000000',
#  'starttime': '20190716000000'}

# %%
jul_19_4 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',jul_19_fun)
jul_19_4
# Out:
# <Response [200]>

# %%
jul_2019_4 = pd.read_csv(io.StringIO(jul_19_4.text) )
jul_2019_4 = jul_2019_4[['Variable','Timestamp','Value','Location (WKT)']]
jul_2019_4
# Out:
#      Variable            Timestamp      Value               Location (WKT)
# 0        PM10  2019-07-16 00:00:00  11.400000  POINT (-1.619756 55.006886)
# 1        PM10  2019-07-16 00:00:00   8.825545  POINT (-1.618791 55.018165)
# 2        PM10  2019-07-16 00:00:00  15.756864  POINT (-1.594308 55.023115)
# 3        PM10  2019-07-16 00:00:00   3.003455  POINT (-1.619875 55.007035)
# 4        PM10  2019-07-16 00:00:00   6.825000     POINT (-1.6135 54.97768)
# ...       ...                  ...        ...                          ...
# 5515     PM10  2019-07-20 23:00:00   1.292857  POINT (-1.619875 55.007035)
# 5516     PM10  2019-07-20 23:00:00   0.648833  POINT (-1.603461 54.965666)
# 5517     PM10  2019-07-20 23:00:00   2.337679  POINT (-1.718833 54.995352)
# 5518     PM10  2019-07-20 23:00:00   2.600000  POINT (-1.617166 54.974211)
# 5519     PM10  2019-07-20 23:00:00   5.003500    POINT (-1.60341 54.96565)
#
# [5520 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,7,21,0)
end_time = datetime.datetime(2019,7,26)
jul_19_fun = func(start_time, end_time)
jul_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20190726000000',
#  'starttime': '20190721000000'}

# %%
jul_19_5 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',jul_19_fun)
jul_19_5
# Out:
# <Response [200]>

# %%
jul_2019_5 = pd.read_csv(io.StringIO(jul_19_5.text) )
jul_2019_5 = jul_2019_5[['Variable','Timestamp','Value','Location (WKT)']]
jul_2019_5
# Out:
#      Variable  ...                             Location (WKT)
# 0        PM10  ...                POINT (-1.619756 55.006886)
# 1        PM10  ...  POINT (-1.5762135386467 54.9843088529622)
# 2        PM10  ...                POINT (-1.584885 54.912025)
# 3        PM10  ...                POINT (-1.603448 54.965685)
# 4        PM10  ...                 POINT (-1.577888 54.98891)
# ...       ...  ...                                        ...
# 5449     PM10  ...                POINT (-1.617166 54.974211)
# 5450     PM10  ...                POINT (-1.558721 54.996494)
# 5451     PM10  ...                POINT (-1.468363 55.015287)
# 5452     PM10  ...                 POINT (-1.45333 55.022829)
# 5453     PM10  ...                POINT (-1.613355 54.977854)
#
# [5454 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,7,26,0)
end_time = datetime.datetime(2019,8,1)
jul_19_fun = func(start_time, end_time)
jul_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20190801000000',
#  'starttime': '20190726000000'}

# %%
jul_19_6 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',jul_19_fun)
jul_19_6
# Out:
# <Response [200]>

# %%
jul_2019_6 = pd.read_csv(io.StringIO(jul_19_6.text) )
jul_2019_6 = jul_2019_6[['Variable','Timestamp','Value','Location (WKT)']]
jul_2019_6
# Out:
#      Variable  ...                       Location (WKT)
# 0        PM10  ...          POINT (-1.619756 55.006886)
# 1        PM10  ...          POINT (-1.558716 54.996502)
# 2        PM10  ...          POINT (-1.550289 54.980095)
# 3        PM10  ...          POINT (-1.609327 54.991308)
# 4        PM10  ...           POINT (-1.543059 55.00026)
# ...       ...  ...                                  ...
# 6475     PM10  ...          POINT (-1.617166 54.974211)
# 6476     PM10  ...           POINT (-1.65862 54.983255)
# 6477     PM10  ...  POINT (-1.210895 54.58024399999999)
# 6478     PM10  ...             POINT (-1.6135 54.97768)
# 6479     PM10  ...          POINT (-1.566521 55.011258)
#
# [6480 rows x 4 columns]

# %%
jul_2019 = pd.concat([jul_2019_1, jul_2019_2, jul_2019_3, jul_2019_4, jul_2019_5, jul_2019_6])
jul_2019
# Out:
#      Variable  ...                             Location (WKT)
# 0        PM10  ...                POINT (-1.619756 55.006886)
# 1        PM10  ...  POINT (-1.5762135386467 54.9843088529622)
# 2        PM10  ...                POINT (-1.590481 55.007634)
# 3        PM10  ...                POINT (-1.566521 55.011258)
# 4        PM10  ...                POINT (-1.593537 55.039309)
# ...       ...  ...                                        ...
# 6475     PM10  ...                POINT (-1.617166 54.974211)
# 6476     PM10  ...                 POINT (-1.65862 54.983255)
# 6477     PM10  ...        POINT (-1.210895 54.58024399999999)
# 6478     PM10  ...                   POINT (-1.6135 54.97768)
# 6479     PM10  ...                POINT (-1.566521 55.011258)
#
# [34086 rows x 4 columns]

# %% [markdown]
# PM10 values of Aug 2019

# %%
start_time = datetime.datetime(2019,8,1,0)
end_time = datetime.datetime(2019,8,6)
aug_19_fun = func(start_time, end_time)
aug_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20190806000000',
#  'starttime': '20190801000000'}

# %%
aug_19_1 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',aug_19_fun)
aug_19_1
# Out:
# <Response [200]>

# %%
aug_2019_1 = pd.read_csv(io.StringIO(aug_19_1.text) )
aug_2019_1 = aug_2019_1[['Variable','Timestamp','Value','Location (WKT)']]
aug_2019_1
# Out:
#      Variable            Timestamp      Value               Location (WKT)
# 0        PM10  2019-08-01 00:00:00  21.070000  POINT (-1.619756 55.006886)
# 1        PM10  2019-08-01 00:00:00   2.517458  POINT (-1.603461 54.965666)
# 2        PM10  2019-08-01 00:00:00   6.969164   POINT (-1.58199 54.984003)
# 3        PM10  2019-08-01 00:00:00  12.005000  POINT (-1.612715 54.975755)
# 4        PM10  2019-08-01 00:00:00   6.692034   POINT (-1.45333 55.022829)
# ...       ...                  ...        ...                          ...
# 5375     PM10  2019-08-05 23:00:00   1.555500  POINT (-1.603461 54.965666)
# 5376     PM10  2019-08-05 23:00:00   3.124000   POINT (-1.45333 55.022829)
# 5377     PM10  2019-08-05 23:00:00   6.637500  POINT (-1.558721 54.996494)
# 5378     PM10  2019-08-05 23:00:00   3.299000  POINT (-1.690413 54.957331)
# 5379     PM10  2019-08-05 23:00:00   8.149714  POINT (-1.618791 55.018165)
#
# [5380 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,8,6,0)
end_time = datetime.datetime(2019,8,11)
aug_19_fun = func(start_time, end_time)
aug_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20190811000000',
#  'starttime': '20190806000000'}

# %%
aug_19_2 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',aug_19_fun)
aug_19_2
# Out:
# <Response [200]>

# %%
aug_2019_2 = pd.read_csv(io.StringIO(aug_19_2.text) )
aug_2019_2 = aug_2019_2[['Variable','Timestamp','Value','Location (WKT)']]
aug_2019_2
# Out:
#      Variable            Timestamp      Value               Location (WKT)
# 0        PM10  2019-08-06 00:00:00   9.164000  POINT (-1.619756 55.006886)
# 1        PM10  2019-08-06 00:00:00   3.386949  POINT (-1.690413 54.957331)
# 2        PM10  2019-08-06 00:00:00  16.590407  POINT (-1.594308 55.023115)
# 3        PM10  2019-08-06 00:00:00   5.756034  POINT (-1.704298 55.000748)
# 4        PM10  2019-08-06 00:00:00   3.943333  POINT (-1.558721 54.996494)
# ...       ...                  ...        ...                          ...
# 5648     PM10  2019-08-10 23:00:00   5.642268   POINT (-1.577888 54.98891)
# 5649     PM10  2019-08-10 23:00:00   2.100000  POINT (-1.606514 54.973793)
# 5650     PM10  2019-08-10 23:00:00   6.081000  POINT (-1.618791 55.018165)
# 5651     PM10  2019-08-10 23:00:00   3.038500    POINT (-1.60341 54.96565)
# 5652     PM10  2019-08-10 23:00:00   7.294643  POINT (-1.759989 54.995961)
#
# [5653 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,8,11,0)
end_time = datetime.datetime(2019,8,16)
aug_19_fun = func(start_time, end_time)
aug_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20190816000000',
#  'starttime': '20190811000000'}

# %%
aug_19_3 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',aug_19_fun)
aug_19_3
# Out:
# <Response [200]>

# %%
aug_2019_3 = pd.read_csv(io.StringIO(aug_19_3.text) )
aug_2019_3 = aug_2019_3[['Variable','Timestamp','Value','Location (WKT)']]
aug_2019_3
# Out:
#      Variable  ...                       Location (WKT)
# 0        PM10  ...          POINT (-1.619756 55.006886)
# 1        PM10  ...           POINT (-1.65862 54.983255)
# 2        PM10  ...          POINT (-1.558721 54.996494)
# 3        PM10  ...          POINT (-1.690413 54.957331)
# 4        PM10  ...          POINT (-1.603448 54.965679)
# ...       ...  ...                                  ...
# 5880     PM10  ...  POINT (-1.210895 54.58024399999999)
# 5881     PM10  ...          POINT (-1.704298 55.000748)
# 5882     PM10  ...          POINT (-1.613355 54.977854)
# 5883     PM10  ...          POINT (-1.603461 54.965666)
# 5884     PM10  ...          POINT (-1.624621 55.007407)
#
# [5885 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,8,16,0)
end_time = datetime.datetime(2019,8,21)
aug_19_fun = func(start_time, end_time)
aug_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20190821000000',
#  'starttime': '20190816000000'}

# %%
aug_19_4 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',aug_19_fun)
aug_19_4
# Out:
# <Response [200]>

# %%
aug_2019_4 = pd.read_csv(io.StringIO(aug_19_4.text) )
aug_2019_4 = aug_2019_4[['Variable','Timestamp','Value','Location (WKT)']]
aug_2019_4
# Out:
#      Variable            Timestamp      Value               Location (WKT)
# 0        PM10  2019-08-16 00:00:00   7.645000  POINT (-1.619756 55.006886)
# 1        PM10  2019-08-16 00:00:00   0.782373  POINT (-1.584885 54.912025)
# 2        PM10  2019-08-16 00:00:00   4.071534   POINT (-1.58199 54.984003)
# 3        PM10  2019-08-16 00:00:00   3.876000  POINT (-1.617166 54.974211)
# 4        PM10  2019-08-16 00:00:00   8.895455  POINT (-1.710721 54.976195)
# ...       ...                  ...        ...                          ...
# 6115     PM10  2019-08-20 23:00:00  10.337500     POINT (-1.6135 54.97768)
# 6116     PM10  2019-08-20 23:00:00  17.654107  POINT (-1.759989 54.995961)
# 6117     PM10  2019-08-20 23:00:00  25.502350  POINT (-1.550289 54.980095)
# 6118     PM10  2019-08-20 23:00:00   3.491167  POINT (-1.690413 54.957331)
# 6119     PM10  2019-08-20 23:00:00  19.227552  POINT (-1.603448 54.965685)
#
# [6120 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,8,21,0)
end_time = datetime.datetime(2019,8,26)
aug_19_fun = func(start_time, end_time)
aug_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20190826000000',
#  'starttime': '20190821000000'}

# %%
aug_19_5 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',aug_19_fun)
aug_19_5
# Out:
# <Response [200]>

# %%
aug_2019_5 = pd.read_csv(io.StringIO(aug_19_5.text) )
aug_2019_5 = aug_2019_5[['Variable','Timestamp','Value','Location (WKT)']]
aug_2019_5
# Out:
#      Variable            Timestamp      Value               Location (WKT)
# 0        PM10  2019-08-21 00:00:00  12.456667  POINT (-1.619756 55.006886)
# 1        PM10  2019-08-21 00:00:00   8.206364   POINT (-1.60345 54.965674)
# 2        PM10  2019-08-21 00:00:00  13.590000  POINT (-1.577439 55.005077)
# 3        PM10  2019-08-21 00:00:00  10.137627  POINT (-1.615699 54.959784)
# 4        PM10  2019-08-21 00:00:00  17.440672  POINT (-1.603448 54.965685)
# ...       ...                  ...        ...                          ...
# 6118     PM10  2019-08-25 23:00:00  11.601667  POINT (-1.593537 55.039309)
# 6119     PM10  2019-08-25 23:00:00  13.178107   POINT (-1.58199 54.984003)
# 6120     PM10  2019-08-25 23:00:00  14.132679  POINT (-1.718833 54.995352)
# 6121     PM10  2019-08-25 23:00:00  15.851250   POINT (-1.60345 54.965674)
# 6122     PM10  2019-08-25 23:00:00  11.700000     POINT (-1.6135 54.97768)
#
# [6123 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,8,26,0)
end_time = datetime.datetime(2019,9,1)
aug_19_fun = func(start_time, end_time)
aug_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20190901000000',
#  'starttime': '20190826000000'}

# %%
aug_19_6 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',aug_19_fun)
aug_19_6
# Out:
# <Response [200]>

# %%
aug_2019_6 = pd.read_csv(io.StringIO(aug_19_6.text) )
aug_2019_6 = aug_2019_6[['Variable','Timestamp','Value','Location (WKT)']]
aug_2019_6
# Out:
#      Variable            Timestamp      Value               Location (WKT)
# 0        PM10  2019-08-26 00:00:00  28.790000  POINT (-1.619756 55.006886)
# 1        PM10  2019-08-26 00:00:00  18.923333  POINT (-1.558721 54.996494)
# 2        PM10  2019-08-26 00:00:00  15.766667  POINT (-1.606514 54.973793)
# 3        PM10  2019-08-26 00:00:00  43.229712  POINT (-1.550289 54.980095)
# 4        PM10  2019-08-26 00:00:00  13.300000     POINT (-1.6135 54.97768)
# ...       ...                  ...        ...                          ...
# 7443     PM10  2019-08-31 23:00:00   7.065250  POINT (-1.558751 54.996488)
# 7444     PM10  2019-08-31 23:00:00   3.582333  POINT (-1.615699 54.959784)
# 7445     PM10  2019-08-31 23:00:00   3.402167   POINT (-1.543059 55.00026)
# 7446     PM10  2019-08-31 23:00:00   3.135000  POINT (-1.612715 54.975755)
# 7447     PM10  2019-08-31 23:00:00   8.912500  POINT (-1.671329 55.053906)
#
# [7448 rows x 4 columns]

# %%
aug_2019 = pd.concat([aug_2019_1, aug_2019_2, aug_2019_3, aug_2019_4, aug_2019_5, aug_2019_6])
aug_2019
# Out:
#      Variable            Timestamp      Value               Location (WKT)
# 0        PM10  2019-08-01 00:00:00  21.070000  POINT (-1.619756 55.006886)
# 1        PM10  2019-08-01 00:00:00   2.517458  POINT (-1.603461 54.965666)
# 2        PM10  2019-08-01 00:00:00   6.969164   POINT (-1.58199 54.984003)
# 3        PM10  2019-08-01 00:00:00  12.005000  POINT (-1.612715 54.975755)
# 4        PM10  2019-08-01 00:00:00   6.692034   POINT (-1.45333 55.022829)
# ...       ...                  ...        ...                          ...
# 7443     PM10  2019-08-31 23:00:00   7.065250  POINT (-1.558751 54.996488)
# 7444     PM10  2019-08-31 23:00:00   3.582333  POINT (-1.615699 54.959784)
# 7445     PM10  2019-08-31 23:00:00   3.402167   POINT (-1.543059 55.00026)
# 7446     PM10  2019-08-31 23:00:00   3.135000  POINT (-1.612715 54.975755)
# 7447     PM10  2019-08-31 23:00:00   8.912500  POINT (-1.671329 55.053906)
#
# [36609 rows x 4 columns]

# %% [markdown]
# PM!0 values of Sept 2019

# %%
start_time = datetime.datetime(2019,9,1,0)
end_time = datetime.datetime(2019,9,6)
sep_19_fun = func(start_time, end_time)
sep_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20190906000000',
#  'starttime': '20190901000000'}

# %%
sep_19_1 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',sep_19_fun)
sep_19_1
# Out:
# <Response [200]>

# %%
sep_2019_1 = pd.read_csv(io.StringIO(sep_19_1.text) )
sep_2019_1 = sep_2019_1[['Variable','Timestamp','Value','Location (WKT)']]
sep_2019_1
# Out:
#      Variable            Timestamp      Value               Location (WKT)
# 0        PM10  2019-09-01 00:00:00   1.410000  POINT (-1.619756 55.006886)
# 1        PM10  2019-09-01 00:00:00   8.440000  POINT (-1.616806 55.009801)
# 2        PM10  2019-09-01 00:00:00  10.667273  POINT (-1.759989 54.995961)
# 3        PM10  2019-09-01 00:00:00   9.100000    POINT (-1.61731 54.97226)
# 4        PM10  2019-09-01 00:00:00   7.425691  POINT (-1.588521 54.998579)
# ...       ...                  ...        ...                          ...
# 6313     PM10  2019-09-05 23:00:00   0.405000  POINT (-1.613355 54.977854)
# 6314     PM10  2019-09-05 23:00:00   9.514783  POINT (-1.566521 55.011258)
# 6315     PM10  2019-09-05 23:00:00   9.155000  POINT (-1.619756 55.006886)
# 6316     PM10  2019-09-05 23:00:00   0.939000  POINT (-1.584885 54.912025)
# 6317     PM10  2019-09-05 23:00:00  11.918883  POINT (-1.550289 54.980095)
#
# [6318 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,9,6,0)
end_time = datetime.datetime(2019,9,11)
sep_19_fun = func(start_time, end_time)
sep_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20190911000000',
#  'starttime': '20190906000000'}

# %%
sep_19_2 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',sep_19_fun)
sep_19_2
# Out:
# <Response [200]>

# %%
sep_2019_2 = pd.read_csv(io.StringIO(sep_19_2.text) )
sep_2019_2 = sep_2019_2[['Variable','Timestamp','Value','Location (WKT)']]
sep_2019_2
# Out:
#      Variable            Timestamp      Value                 Location (WKT)
# 0        PM10  2019-09-06 00:00:00   9.238000    POINT (-1.619756 55.006886)
# 1        PM10  2019-09-06 00:00:00   0.865932    POINT (-1.584885 54.912025)
# 2        PM10  2019-09-06 00:00:00   6.932500       POINT (-1.6135 54.97768)
# 3        PM10  2019-09-06 00:00:00   8.322220    POINT (-1.618791 55.018165)
# 4        PM10  2019-09-06 00:00:00   7.485881     POINT (-1.577888 54.98891)
# ...       ...                  ...        ...                            ...
# 6502     PM10  2019-09-10 23:00:00  15.198417    POINT (-1.594308 55.023115)
# 6503     PM10  2019-09-10 23:00:00   2.523333     POINT (-1.45333 55.022829)
# 6504     PM10  2019-09-10 23:00:00   2.989286     POINT (-1.60345 54.965674)
# 6505     PM10  2019-09-10 23:00:00   9.580000    POINT (-1.616806 55.009801)
# 6506     PM10  2019-09-10 23:00:00   4.414500  POINT (-1.6112187 54.9736679)
#
# [6507 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,9,11,0)
end_time = datetime.datetime(2019,9,16)
sep_19_fun = func(start_time, end_time)
sep_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20190916000000',
#  'starttime': '20190911000000'}

# %%
sep_19_3 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',sep_19_fun)
sep_19_3
# Out:
# <Response [200]>

# %%
sep_2019_3 = pd.read_csv(io.StringIO(sep_19_3.text) )
sep_2019_3 = sep_2019_3[['Variable','Timestamp','Value','Location (WKT)']]
sep_2019_3
# Out:
#      Variable            Timestamp      Value               Location (WKT)
# 0        PM10  2019-09-11 00:00:00   3.024333  POINT (-1.619756 55.006886)
# 1        PM10  2019-09-11 00:00:00   2.900000    POINT (-1.61169 54.97431)
# 2        PM10  2019-09-11 00:00:00   6.864255  POINT (-1.618791 55.018165)
# 3        PM10  2019-09-11 00:00:00   4.158400   POINT (-1.58199 54.984003)
# 4        PM10  2019-09-11 00:00:00   6.799491  POINT (-1.590481 55.007634)
# ...       ...                  ...        ...                          ...
# 6618     PM10  2019-09-15 23:00:00   7.674143   POINT (-1.58199 54.984003)
# 6619     PM10  2019-09-15 23:00:00   7.697321  POINT (-1.603448 54.965679)
# 6620     PM10  2019-09-15 23:00:00   4.783833   POINT (-1.45333 55.022829)
# 6621     PM10  2019-09-15 23:00:00   4.808500  POINT (-1.468363 55.015287)
# 6622     PM10  2019-09-15 23:00:00  14.240000  POINT (-1.617206 55.014544)
#
# [6623 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,9,16,0)
end_time = datetime.datetime(2019,9,21)
sep_19_fun = func(start_time, end_time)
sep_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20190921000000',
#  'starttime': '20190916000000'}

# %%
sep_19_4 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',sep_19_fun)
sep_19_4
# Out:
# <Response [200]>

# %%
sep_2019_4 = pd.read_csv(io.StringIO(sep_19_4.text) )
sep_2019_4 = sep_2019_4[['Variable','Timestamp','Value','Location (WKT)']]
sep_2019_4
# Out:
#      Variable            Timestamp       Value               Location (WKT)
# 0        PM10  2019-09-16 00:00:00   13.770000  POINT (-1.619756 55.006886)
# 1        PM10  2019-09-16 00:00:00    8.392500    POINT (-1.61731 54.97226)
# 2        PM10  2019-09-16 00:00:00    7.882000  POINT (-1.603448 54.965679)
# 3        PM10  2019-09-16 00:00:00    6.387500  POINT (-1.612715 54.975755)
# 4        PM10  2019-09-16 00:00:00    0.385000  POINT (-1.613355 54.977854)
# ...       ...                  ...         ...                          ...
# 6717     PM10  2019-09-20 23:00:00    6.893036  POINT (-1.521943 55.029411)
# 6718     PM10  2019-09-20 23:00:00   19.378214  POINT (-1.759989 54.995961)
# 6719     PM10  2019-09-20 23:00:00    7.940000    POINT (-1.61014 54.97461)
# 6720     PM10  2019-09-20 23:00:00  326.502679  POINT (-1.718833 54.995352)
# 6721     PM10  2019-09-20 23:00:00    9.178429  POINT (-1.609327 54.991308)
#
# [6722 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,9,21,0)
end_time = datetime.datetime(2019,9,26)
sep_19_fun = func(start_time, end_time)
sep_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20190926000000',
#  'starttime': '20190921000000'}

# %%
sep_19_5 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',sep_19_fun)
sep_19_5
# Out:
# <Response [200]>

# %%
sep_2019_5 = pd.read_csv(io.StringIO(sep_19_5.text) )
sep_2019_5 = sep_2019_5[['Variable','Timestamp','Value','Location (WKT)']]
sep_2019_5
# Out:
#      Variable            Timestamp      Value               Location (WKT)
# 0        PM10  2019-09-21 00:00:00  16.343333  POINT (-1.619756 55.006886)
# 1        PM10  2019-09-21 00:00:00   9.839091  POINT (-1.558721 54.996494)
# 2        PM10  2019-09-21 00:00:00  17.182203   POINT (-1.543059 55.00026)
# 3        PM10  2019-09-21 00:00:00   4.458727  POINT (-1.619875 55.007035)
# 4        PM10  2019-09-21 00:00:00   7.757455  POINT (-1.603448 54.965679)
# ...       ...                  ...        ...                          ...
# 6601     PM10  2019-09-25 23:00:00  32.260000  POINT (-1.624621 55.007407)
# 6602     PM10  2019-09-25 23:00:00  17.811650  POINT (-1.566521 55.011258)
# 6603     PM10  2019-09-25 23:00:00   9.956105   POINT (-1.577888 54.98891)
# 6604     PM10  2019-09-25 23:00:00   6.861053  POINT (-1.619875 55.007035)
# 6605     PM10  2019-09-25 23:00:00   2.694833  POINT (-1.584885 54.912025)
#
# [6606 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,9,26,0)
end_time = datetime.datetime(2019,10,1)
sep_19_fun = func(start_time, end_time)
sep_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20191001000000',
#  'starttime': '20190926000000'}

# %%
sep_19_6 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',sep_19_fun)
sep_19_6
# Out:
# <Response [200]>

# %%
sep_2019_6 = pd.read_csv(io.StringIO(sep_19_6.text) )
sep_2019_6 = sep_2019_6[['Variable','Timestamp','Value','Location (WKT)']]
sep_2019_6
# Out:
#      Variable  ...                             Location (WKT)
# 0        PM10  ...                POINT (-1.619756 55.006886)
# 1        PM10  ...                POINT (-1.609327 54.991308)
# 2        PM10  ...                POINT (-1.558721 54.996494)
# 3        PM10  ...                POINT (-1.606514 54.973793)
# 4        PM10  ...                 POINT (-1.58199 54.984003)
# ...       ...  ...                                        ...
# 6595     PM10  ...                POINT (-1.710531 54.991754)
# 6596     PM10  ...                POINT (-1.613355 54.977854)
# 6597     PM10  ...  POINT (-1.5762135386467 54.9843088529622)
# 6598     PM10  ...                POINT (-1.704298 55.000748)
# 6599     PM10  ...                POINT (-1.603448 54.965685)
#
# [6600 rows x 4 columns]

# %%
sep_2019 = pd.concat([sep_2019_1, sep_2019_2, sep_2019_3, sep_2019_4, sep_2019_5, sep_2019_6])
sep_2019
# Out:
#      Variable  ...                             Location (WKT)
# 0        PM10  ...                POINT (-1.619756 55.006886)
# 1        PM10  ...                POINT (-1.616806 55.009801)
# 2        PM10  ...                POINT (-1.759989 54.995961)
# 3        PM10  ...                  POINT (-1.61731 54.97226)
# 4        PM10  ...                POINT (-1.588521 54.998579)
# ...       ...  ...                                        ...
# 6595     PM10  ...                POINT (-1.710531 54.991754)
# 6596     PM10  ...                POINT (-1.613355 54.977854)
# 6597     PM10  ...  POINT (-1.5762135386467 54.9843088529622)
# 6598     PM10  ...                POINT (-1.704298 55.000748)
# 6599     PM10  ...                POINT (-1.603448 54.965685)
#
# [39376 rows x 4 columns]

# %% [markdown]
# PM10 Values of Oct 2019

# %%
start_time = datetime.datetime(2019,10,1,0)
end_time = datetime.datetime(2019,10,6)
oct_19_fun = func(start_time, end_time)
oct_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20191006000000',
#  'starttime': '20191001000000'}

# %%
oct_19_1 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',oct_19_fun)
oct_19_1
# Out:
# <Response [200]>

# %%
oct_2019_1 = pd.read_csv(io.StringIO(oct_19_1.text) )
oct_2019_1 = oct_2019_1[['Variable','Timestamp','Value','Location (WKT)']]
oct_2019_1
# Out:
#      Variable  ...                             Location (WKT)
# 0        PM10  ...                POINT (-1.619756 55.006886)
# 1        PM10  ...  POINT (-1.5762135386467 54.9843088529622)
# 2        PM10  ...                POINT (-1.558721 54.996494)
# 3        PM10  ...                POINT (-1.718833 54.995352)
# 4        PM10  ...                POINT (-1.606514 54.973793)
# ...       ...  ...                                        ...
# 6605     PM10  ...                POINT (-1.588521 54.998579)
# 6606     PM10  ...                POINT (-1.704298 55.000748)
# 6607     PM10  ...                POINT (-1.710531 54.991754)
# 6608     PM10  ...                POINT (-1.624621 55.007407)
# 6609     PM10  ...                POINT (-1.603461 54.965666)
#
# [6610 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,10,6,0)
end_time = datetime.datetime(2019,10,11)
oct_19_fun = func(start_time, end_time)
oct_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20191011000000',
#  'starttime': '20191006000000'}

# %%
oct_19_2 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',oct_19_fun)
oct_19_2
# Out:
# <Response [200]>

# %%
oct_2019_2 = pd.read_csv(io.StringIO(oct_19_2.text) )
oct_2019_2 = oct_2019_2[['Variable','Timestamp','Value','Location (WKT)']]
oct_2019_2
# Out:
#      Variable            Timestamp      Value                 Location (WKT)
# 0        PM10  2019-10-06 00:00:00   7.149333    POINT (-1.619756 55.006886)
# 1        PM10  2019-10-06 00:00:00  11.215000    POINT (-1.617166 54.974211)
# 2        PM10  2019-10-06 00:00:00  16.613091    POINT (-1.759989 54.995961)
# 3        PM10  2019-10-06 00:00:00   9.608000     POINT (-1.65862 54.983255)
# 4        PM10  2019-10-06 00:00:00   7.361000  POINT (-1.6112187 54.9736679)
# ...       ...                  ...        ...                            ...
# 6617     PM10  2019-10-10 23:00:00   3.664643    POINT (-1.603448 54.965679)
# 6618     PM10  2019-10-10 23:00:00   7.610667    POINT (-1.550289 54.980095)
# 6619     PM10  2019-10-10 23:00:00   1.086667    POINT (-1.584885 54.912025)
# 6620     PM10  2019-10-10 23:00:00   5.470000      POINT (-1.61169 54.97431)
# 6621     PM10  2019-10-10 23:00:00   5.308983    POINT (-1.637606 54.969172)
#
# [6622 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,10,11,0)
end_time = datetime.datetime(2019,10,16)
oct_19_fun = func(start_time, end_time)
oct_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20191016000000',
#  'starttime': '20191011000000'}

# %%
oct_19_3 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',oct_19_fun)
oct_19_3
# Out:
# <Response [200]>

# %%
oct_2019_3 = pd.read_csv(io.StringIO(oct_19_3.text) )
oct_2019_3 = oct_2019_3[['Variable','Timestamp','Value','Location (WKT)']]
oct_2019_3
# Out:
#      Variable            Timestamp      Value                 Location (WKT)
# 0        PM10  2019-10-11 00:00:00   3.341000    POINT (-1.619756 55.006886)
# 1        PM10  2019-10-11 00:00:00   8.237055    POINT (-1.553981 54.951477)
# 2        PM10  2019-10-11 00:00:00   5.996441    POINT (-1.566521 55.011258)
# 3        PM10  2019-10-11 00:00:00   2.636364    POINT (-1.611256 55.012987)
# 4        PM10  2019-10-11 00:00:00   0.225000    POINT (-1.613355 54.977854)
# ...       ...                  ...        ...                            ...
# 6608     PM10  2019-10-15 23:00:00  43.031250    POINT (-1.637606 54.969172)
# 6609     PM10  2019-10-15 23:00:00  18.082500  POINT (-1.6112187 54.9736679)
# 6610     PM10  2019-10-15 23:00:00  16.064821    POINT (-1.611256 55.012987)
# 6611     PM10  2019-10-15 23:00:00  44.256167    POINT (-1.550289 54.980095)
# 6612     PM10  2019-10-15 23:00:00  34.430000    POINT (-1.617206 55.014544)
#
# [6613 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,10,16,0)
end_time = datetime.datetime(2019,10,21)
oct_19_fun = func(start_time, end_time)
oct_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20191021000000',
#  'starttime': '20191016000000'}

# %%
oct_19_4 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',oct_19_fun)
oct_19_4
# Out:
# <Response [200]>

# %%
oct_2019_4 = pd.read_csv(io.StringIO(oct_19_4.text) )
oct_2019_4 = oct_2019_4[['Variable','Timestamp','Value','Location (WKT)']]
oct_2019_4
# Out:
#      Variable  ...                       Location (WKT)
# 0        PM10  ...          POINT (-1.619756 55.006886)
# 1        PM10  ...          POINT (-1.558721 54.996494)
# 2        PM10  ...          POINT (-1.590481 55.007634)
# 3        PM10  ...          POINT (-1.606514 54.973793)
# 4        PM10  ...          POINT (-1.583808 54.991155)
# ...       ...  ...                                  ...
# 6715     PM10  ...            POINT (-1.60341 54.96565)
# 6716     PM10  ...          POINT (-1.603461 54.965666)
# 6717     PM10  ...          POINT (-1.558716 54.996502)
# 6718     PM10  ...          POINT (-1.594308 55.023115)
# 6719     PM10  ...  POINT (-1.210895 54.58024399999999)
#
# [6720 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,10,21,0)
end_time = datetime.datetime(2019,10,26)
oct_19_fun = func(start_time, end_time)
oct_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20191026000000',
#  'starttime': '20191021000000'}

# %%
oct_19_5 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',oct_19_fun)
oct_19_5
# Out:
# <Response [200]>

# %%
oct_2019_5 = pd.read_csv(io.StringIO(oct_19_5.text) )
oct_2019_5 = oct_2019_5[['Variable','Timestamp','Value','Location (WKT)']]
oct_2019_5
# Out:
#      Variable  ...                       Location (WKT)
# 0        PM10  ...          POINT (-1.619756 55.006886)
# 1        PM10  ...          POINT (-1.558721 54.996494)
# 2        PM10  ...          POINT (-1.590481 55.007634)
# 3        PM10  ...          POINT (-1.606514 54.973793)
# 4        PM10  ...          POINT (-1.583808 54.991155)
# ...       ...  ...                                  ...
# 6715     PM10  ...            POINT (-1.60341 54.96565)
# 6716     PM10  ...          POINT (-1.603461 54.965666)
# 6717     PM10  ...          POINT (-1.558716 54.996502)
# 6718     PM10  ...          POINT (-1.594308 55.023115)
# 6719     PM10  ...  POINT (-1.210895 54.58024399999999)
#
# [6720 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,10,26,0)
end_time = datetime.datetime(2019,11,1)
oct_19_fun = func(start_time, end_time)
oct_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20191101000000',
#  'starttime': '20191026000000'}

# %%
oct_19_6 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',oct_19_fun)
oct_19_6
# Out:
# <Response [200]>

# %%
oct_2019_6 = pd.read_csv(io.StringIO(oct_19_6.text) )
oct_2019_6 = oct_2019_6[['Variable','Timestamp','Value','Location (WKT)']]
oct_2019_6
# Out:
#      Variable            Timestamp      Value               Location (WKT)
# 0        PM10  2019-10-26 00:00:00   2.425000  POINT (-1.619756 55.006886)
# 1        PM10  2019-10-26 00:00:00   5.590000  POINT (-1.577439 55.005077)
# 2        PM10  2019-10-26 00:00:00   3.826727  POINT (-1.558721 54.996494)
# 3        PM10  2019-10-26 00:00:00   1.327627  POINT (-1.690413 54.957331)
# 4        PM10  2019-10-26 00:00:00   6.598309  POINT (-1.618791 55.018165)
# ...       ...                  ...        ...                          ...
# 7983     PM10  2019-10-31 23:00:00  10.862500   POINT (-1.45333 55.022829)
# 7984     PM10  2019-10-31 23:00:00  24.167857  POINT (-1.558721 54.996494)
# 7985     PM10  2019-10-31 23:00:00  22.433393  POINT (-1.618791 55.018165)
# 7986     PM10  2019-10-31 23:00:00  12.525167  POINT (-1.468363 55.015287)
# 7987     PM10  2019-10-31 23:00:00  26.886786   POINT (-1.65862 54.983255)
#
# [7988 rows x 4 columns]

# %%
oct_2019 = pd.concat([oct_2019_1, oct_2019_2, oct_2019_3, oct_2019_4, oct_2019_5, oct_2019_6])
oct_2019
# Out:
#      Variable  ...                             Location (WKT)
# 0        PM10  ...                POINT (-1.619756 55.006886)
# 1        PM10  ...  POINT (-1.5762135386467 54.9843088529622)
# 2        PM10  ...                POINT (-1.558721 54.996494)
# 3        PM10  ...                POINT (-1.718833 54.995352)
# 4        PM10  ...                POINT (-1.606514 54.973793)
# ...       ...  ...                                        ...
# 7983     PM10  ...                 POINT (-1.45333 55.022829)
# 7984     PM10  ...                POINT (-1.558721 54.996494)
# 7985     PM10  ...                POINT (-1.618791 55.018165)
# 7986     PM10  ...                POINT (-1.468363 55.015287)
# 7987     PM10  ...                 POINT (-1.65862 54.983255)
#
# [41273 rows x 4 columns]

# %% [markdown]
# PM10 values of Nov 2019

# %%
start_time = datetime.datetime(2019,11,1,0)
end_time = datetime.datetime(2019,11,6)
nov_19_fun = func(start_time, end_time)
nov_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20191106000000',
#  'starttime': '20191101000000'}

# %%
nov_19_1 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',nov_19_fun)
nov_19_1
# Out:
# <Response [200]>

# %%
nov_2019_1 = pd.read_csv(io.StringIO(nov_19_1.text) )
nov_2019_1 = nov_2019_1[['Variable','Timestamp','Value','Location (WKT)']]
nov_2019_1
# Out:
#      Variable            Timestamp      Value               Location (WKT)
# 0        PM10  2019-11-01 00:00:00  28.656667  POINT (-1.619756 55.006886)
# 1        PM10  2019-11-01 00:00:00  38.315000  POINT (-1.558721 54.996494)
# 2        PM10  2019-11-01 00:00:00  26.980727   POINT (-1.65862 54.983255)
# 3        PM10  2019-11-01 00:00:00  26.891475  POINT (-1.558716 54.996502)
# 4        PM10  2019-11-01 00:00:00  25.027273  POINT (-1.558721 54.996494)
# ...       ...                  ...        ...                          ...
# 6600     PM10  2019-11-05 23:00:00  13.537500  POINT (-1.558721 54.996494)
# 6601     PM10  2019-11-05 23:00:00  18.862500    POINT (-1.61731 54.97226)
# 6602     PM10  2019-11-05 23:00:00   8.014750  POINT (-1.558751 54.996488)
# 6603     PM10  2019-11-05 23:00:00  10.590357  POINT (-1.618791 55.018165)
# 6604     PM10  2019-11-05 23:00:00  10.065607   POINT (-1.577888 54.98891)
#
# [6605 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,11,6,0)
end_time = datetime.datetime(2019,11,11)
nov_19_fun = func(start_time, end_time)
nov_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20191111000000',
#  'starttime': '20191106000000'}

# %%
nov_19_2 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',nov_19_fun)
nov_19_2
# Out:
# <Response [200]>

# %%
nov_2019_2 = pd.read_csv(io.StringIO(nov_19_2.text) )
nov_2019_2 = nov_2019_2[['Variable','Timestamp','Value','Location (WKT)']]
nov_2019_2
# Out:
#      Variable            Timestamp      Value               Location (WKT)
# 0        PM10  2019-11-06 00:00:00   8.655667  POINT (-1.619756 55.006886)
# 1        PM10  2019-11-06 00:00:00  10.100182  POINT (-1.637606 54.969172)
# 2        PM10  2019-11-06 00:00:00  12.694218  POINT (-1.590481 55.007634)
# 3        PM10  2019-11-06 00:00:00   8.329455  POINT (-1.603448 54.965679)
# 4        PM10  2019-11-06 00:00:00   4.232373  POINT (-1.690413 54.957331)
# ...       ...                  ...        ...                          ...
# 6601     PM10  2019-11-10 23:00:00  32.380000  POINT (-1.759989 54.995961)
# 6602     PM10  2019-11-10 23:00:00   8.792857  POINT (-1.603448 54.965679)
# 6603     PM10  2019-11-10 23:00:00  17.856429  POINT (-1.718833 54.995352)
# 6604     PM10  2019-11-10 23:00:00   4.090833   POINT (-1.45333 55.022829)
# 6605     PM10  2019-11-10 23:00:00   9.232500    POINT (-1.61014 54.97461)
#
# [6606 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,11,11,0)
end_time = datetime.datetime(2019,11,16)
nov_19_fun = func(start_time, end_time)
nov_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20191116000000',
#  'starttime': '20191111000000'}

# %%
nov_19_3 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',nov_19_fun)
nov_19_3
# Out:
# <Response [200]>

# %%
nov_2019_3 = pd.read_csv(io.StringIO(nov_19_3.text) )
nov_2019_3 = nov_2019_3[['Variable','Timestamp','Value','Location (WKT)']]
nov_2019_3
# Out:
#      Variable            Timestamp      Value               Location (WKT)
# 0        PM10  2019-11-11 00:00:00  10.636667  POINT (-1.619756 55.006886)
# 1        PM10  2019-11-11 00:00:00  10.529831  POINT (-1.615699 54.959784)
# 2        PM10  2019-11-11 00:00:00  12.243333  POINT (-1.558751 54.996488)
# 3        PM10  2019-11-11 00:00:00  18.433333  POINT (-1.624621 55.007407)
# 4        PM10  2019-11-11 00:00:00  15.699273  POINT (-1.718833 54.995352)
# ...       ...                  ...        ...                          ...
# 6609     PM10  2019-11-15 23:00:00   3.574167  POINT (-1.603461 54.965666)
# 6610     PM10  2019-11-15 23:00:00   7.795000  POINT (-1.558721 54.996494)
# 6611     PM10  2019-11-15 23:00:00  12.159732  POINT (-1.609327 54.991308)
# 6612     PM10  2019-11-15 23:00:00  14.417321  POINT (-1.704298 55.000748)
# 6613     PM10  2019-11-15 23:00:00  15.985000  POINT (-1.617206 55.014544)
#
# [6614 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,11,16,0)
end_time = datetime.datetime(2019,11,21)
nov_19_fun = func(start_time, end_time)
nov_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20191121000000',
#  'starttime': '20191116000000'}

# %%
nov_19_4 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',nov_19_fun)
nov_19_4
# Out:
# <Response [200]>

# %%
nov_2019_4 = pd.read_csv(io.StringIO(nov_19_4.text) )
nov_2019_4 = nov_2019_4[['Variable','Timestamp','Value','Location (WKT)']]
nov_2019_4
# Out:
#      Variable            Timestamp      Value               Location (WKT)
# 0        PM10  2019-11-16 00:00:00  19.580000  POINT (-1.619756 55.006886)
# 1        PM10  2019-11-16 00:00:00  18.200424  POINT (-1.558716 54.996502)
# 2        PM10  2019-11-16 00:00:00   5.966667  POINT (-1.558721 54.996494)
# 3        PM10  2019-11-16 00:00:00  27.534364  POINT (-1.759989 54.995961)
# 4        PM10  2019-11-16 00:00:00  16.859055  POINT (-1.588521 54.998579)
# ...       ...                  ...        ...                          ...
# 6760     PM10  2019-11-20 23:00:00   8.195000    POINT (-1.61169 54.97431)
# 6761     PM10  2019-11-20 23:00:00   5.577500  POINT (-1.606514 54.973793)
# 6762     PM10  2019-11-20 23:00:00   1.738333  POINT (-1.584885 54.912025)
# 6763     PM10  2019-11-20 23:00:00  11.321071  POINT (-1.637606 54.969172)
# 6764     PM10  2019-11-20 23:00:00  10.781411  POINT (-1.618791 55.018165)
#
# [6765 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,11,21,0)
end_time = datetime.datetime(2019,11,26)
nov_19_fun = func(start_time, end_time)
nov_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20191126000000',
#  'starttime': '20191121000000'}

# %%
nov_19_5 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',nov_19_fun)
nov_19_5
# Out:
# <Response [200]>

# %%
nov_2019_5 = pd.read_csv(io.StringIO(nov_19_5.text) )
nov_2019_5 = nov_2019_5[['Variable','Timestamp','Value','Location (WKT)']]
nov_2019_5
# Out:
#      Variable            Timestamp      Value               Location (WKT)
# 0        PM10  2019-11-21 00:00:00  14.686667  POINT (-1.619756 55.006886)
# 1        PM10  2019-11-21 00:00:00   9.286667    POINT (-1.61169 54.97431)
# 2        PM10  2019-11-21 00:00:00  13.352500  POINT (-1.558721 54.996494)
# 3        PM10  2019-11-21 00:00:00   1.467500  POINT (-1.613355 54.977854)
# 4        PM10  2019-11-21 00:00:00  10.885000  POINT (-1.612715 54.975755)
# ...       ...                  ...        ...                          ...
# 6719     PM10  2019-11-25 23:00:00  17.298800  POINT (-1.583808 54.991155)
# 6720     PM10  2019-11-25 23:00:00  17.704804   POINT (-1.58199 54.984003)
# 6721     PM10  2019-11-25 23:00:00  15.582500   POINT (-1.60345 54.965674)
# 6722     PM10  2019-11-25 23:00:00  23.152500  POINT (-1.558721 54.996494)
# 6723     PM10  2019-11-25 23:00:00  31.262267  POINT (-1.550289 54.980095)
#
# [6724 rows x 4 columns]

# %%
start_time = datetime.datetime(2019,11,26,0)
end_time = datetime.datetime(2020,12,1)
nov_19_fun = func(start_time, end_time)
nov_19_fun
# Out:
# {'agg_method': 'mean',
#  'agg_period': '1hour',
#  'data_variable': 'PM10',
#  'endtime': '20201201000000',
#  'starttime': '20191126000000'}

# %%
nov_19_6 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',nov_19_fun)
nov_19_6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-96-65f8fc25f20b> in <module>()
# ----> 1 nov_19_6 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',nov_19_fun)
#       2 nov_19_6
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.7/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.7/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# /usr/lib/python3.7/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
nov_2019_6 = pd.read_csv(io.StringIO(nov_19_6.text) )
nov_2019_6 = nov_2019_6[['Variable','Timestamp','Value','Location (WKT)']]
nov_2019_6

# %%
nov_2019 = pd.concat([nov_2019_1, nov_2019_2, nov_2019_3, nov_2019_4, nov_2019_5, nov_2019_6])
nov_2019

# %% [markdown]
# PM10 values of Dec 2019

# %%
start_time = datetime.datetime(2019,12,1,0)
end_time = datetime.datetime(2019,12,6)
dec_19_fun = func(start_time, end_time)
dec_19_fun

# %%
dec_19_1 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',dec_19_fun)
dec_19_1

# %%
dec_2019_1 = pd.read_csv(io.StringIO(dec_19_1.text) )
dec_2019_1 = dec_2019_1[['Variable','Timestamp','Value','Location (WKT)']]
dec_2019_1

# %%
start_time = datetime.datetime(2019,12,6,0)
end_time = datetime.datetime(2019,12,11)
dec_19_fun = func(start_time, end_time)
dec_19_fun

# %%
dec_19_2 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',dec_19_fun)
dec_19_2

# %%
dec_2019_2 = pd.read_csv(io.StringIO(dec_19_2.text) )
dec_2019_2 = dec_2019_2[['Variable','Timestamp','Value','Location (WKT)']]
dec_2019_2

# %%
start_time = datetime.datetime(2019,12,11,0)
end_time = datetime.datetime(2019,12,16)
dec_19_fun = func(start_time, end_time)
dec_19_fun

# %%
dec_19_3 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',dec_19_fun)
dec_19_3

# %%
dec_2019_3 = pd.read_csv(io.StringIO(dec_19_3.text) )
dec_2019_3 = dec_2019_3[['Variable','Timestamp','Value','Location (WKT)']]
dec_2019_3

# %%
start_time = datetime.datetime(2019,12,16,0)
end_time = datetime.datetime(2019,12,21)
dec_19_fun = func(start_time, end_time)
dec_19_fun

# %%
dec_19_4 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',dec_19_fun)
dec_19_4

# %%
dec_2019_4 = pd.read_csv(io.StringIO(dec_19_4.text) )
dec_2019_4 = dec_2019_4[['Variable','Timestamp','Value','Location (WKT)']]
dec_2019_4

# %%
start_time = datetime.datetime(2019,12,21,0)
end_time = datetime.datetime(2019,12,26)
dec_19_fun = func(start_time, end_time)
dec_19_fun

# %%
dec_19_5 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',dec_19_fun)
dec_19_5

# %%
dec_2019_5 = pd.read_csv(io.StringIO(dec_19_5.text) )
dec_2019_5 = dec_2019_5[['Variable','Timestamp','Value','Location (WKT)']]
dec_2019_5

# %%
start_time = datetime.datetime(2019,12,26,0)
end_time = datetime.datetime(2020,1,1)
dec_19_fun = func(start_time, end_time)
dec_19_fun

# %%
dec_19_6 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',dec_19_fun)
dec_19_6

# %%
dec_2019_6 = pd.read_csv(io.StringIO(dec_19_6.text) )
dec_2019_6 = dec_2019_6[['Variable','Timestamp','Value','Location (WKT)']]
dec_2019_6

# %%
dec_2019 = pd.concat([dec_2019_1, dec_2019_2, dec_2019_3, dec_2019_4, dec_2019_5, dec_2019_6])
dec_2019

# %% [markdown]
# PM10 values of Jan 2020

# %%
start_time = datetime.datetime(2020,1,1,0)
end_time = datetime.datetime(2020,1,6)
jan_20_fun = func(start_time, end_time)
jan_20_fun

# %%
jan_20_1 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',jan_20_fun)
jan_20_1

# %%
jan_2020_1 = pd.read_csv(io.StringIO(jan_20_1.text) )
jan_2020_1 = jan_2020_1[['Variable','Timestamp','Value','Location (WKT)']]
jan_2020_1

# %%
start_time = datetime.datetime(2020,1,6,0)
end_time = datetime.datetime(2020,1,11)
jan_20_fun = func(start_time, end_time)
jan_20_fun

# %%
jan_20_2 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',jan_20_fun)
jan_20_2

# %%
jan_2020_2 = pd.read_csv(io.StringIO(jan_20_2.text) )
jan_2020_2 = jan_2020_2[['Variable','Timestamp','Value','Location (WKT)']]
jan_2020_2

# %%
start_time = datetime.datetime(2020,1,11,0)
end_time = datetime.datetime(2020,1,16)
jan_20_fun = func(start_time, end_time)
jan_20_fun

# %%
jan_20_3 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',jan_20_fun)
jan_20_3

# %%
jan_2020_3 = pd.read_csv(io.StringIO(jan_20_3.text) )
jan_2020_3 = jan_2020_3[['Variable','Timestamp','Value','Location (WKT)']]
jan_2020_3

# %%
start_time = datetime.datetime(2020,1,16,0)
end_time = datetime.datetime(2020,1,21)
jan_20_fun = func(start_time, end_time)
jan_20_fun

# %%
jan_20_4 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',jan_20_fun)
jan_20_4

# %%
jan_2020_4 = pd.read_csv(io.StringIO(jan_20_4.text) )
jan_2020_4 = jan_2020_4[['Variable','Timestamp','Value','Location (WKT)']]
jan_2020_4

# %%
start_time = datetime.datetime(2020,1,21,0)
end_time = datetime.datetime(2020,1,26)
jan_20_fun = func(start_time, end_time)
jan_20_fun

# %%
jan_20_5 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',jan_20_fun)
jan_20_5

# %%
jan_2020_5 = pd.read_csv(io.StringIO(jan_20_5.text) )
jan_2020_5 = jan_2020_5[['Variable','Timestamp','Value','Location (WKT)']]
jan_2020_5

# %%
start_time = datetime.datetime(2020,1,26,0)
end_time = datetime.datetime(2020,2,1)
jan_20_fun = func(start_time, end_time)
jan_20_fun

# %%
jan_20_6 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',jan_20_fun)
jan_20_6

# %%
jan_2020_6 = pd.read_csv(io.StringIO(jan_20_6.text) )
jan_2020_6 = jan_2020_6[['Variable','Timestamp','Value','Location (WKT)']]
jan_2020_6

# %%
jan_2020 = pd.concat([jan_2020_1, jan_2020_2, jan_2020_3, jan_2020_4, jan_2020_5, jan_2020_6])
jan_2020

# %% [markdown]
# PM10 values of Feb 2020

# %%
start_time = datetime.datetime(2020,2,1,0)
end_time = datetime.datetime(2020,2,6)
feb_20_fun = func(start_time, end_time)
feb_20_fun

# %%
feb_20_1 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',feb_20_fun)
feb_20_1

# %%
feb_2020_1 = pd.read_csv(io.StringIO(feb_20_1.text) )
feb_2020_1 = feb_2020_1[['Variable','Timestamp','Value','Location (WKT)']]
feb_2020_1

# %%
start_time = datetime.datetime(2020,2,6,0)
end_time = datetime.datetime(2020,2,11)
feb_20_fun = func(start_time, end_time)
feb_20_fun

# %%
feb_20_2 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',feb_20_fun)
feb_20_2

# %%
feb_2020_2 = pd.read_csv(io.StringIO(feb_20_2.text) )
feb_2020_2 = feb_2020_2[['Variable','Timestamp','Value','Location (WKT)']]
feb_2020_2

# %%
start_time = datetime.datetime(2020,2,11,0)
end_time = datetime.datetime(2020,2,16)
feb_20_fun = func(start_time, end_time)
feb_20_fun

# %%
feb_20_3 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',feb_20_fun)
feb_20_3

# %%
feb_2020_3 = pd.read_csv(io.StringIO(feb_20_3.text) )
feb_2020_3 = feb_2020_3[['Variable','Timestamp','Value','Location (WKT)']]
feb_2020_3

# %%
start_time = datetime.datetime(2020,2,16,0)
end_time = datetime.datetime(2020,2,21)
feb_20_fun = func(start_time, end_time)
feb_20_fun

# %%
feb_20_4 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',feb_20_fun)
feb_20_4

# %%
feb_2020_4 = pd.read_csv(io.StringIO(feb_20_4.text) )
feb_2020_4 = feb_2020_4[['Variable','Timestamp','Value','Location (WKT)']]
feb_2020_4

# %%
start_time = datetime.datetime(2020,2,21,0)
end_time = datetime.datetime(2020,2,26)
feb_20_fun = func(start_time, end_time)
feb_20_fun

# %%
feb_20_5 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',feb_20_fun)
feb_20_5

# %%
feb_2020_5 = pd.read_csv(io.StringIO(feb_20_5.text) )
feb_2020_5 = feb_2020_5[['Variable','Timestamp','Value','Location (WKT)']]
feb_2020_5

# %%
start_time = datetime.datetime(2020,2,26,0)
end_time = datetime.datetime(2020,3,1)
feb_20_fun = func(start_time, end_time)
feb_20_fun

# %%
feb_20_6 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',feb_20_fun)
feb_20_6

# %%
feb_2020_6 = pd.read_csv(io.StringIO(feb_20_6.text) )
feb_2020_6 = feb_2020_6[['Variable','Timestamp','Value','Location (WKT)']]
feb_2020_6

# %%
feb_2020 = pd.concat([feb_2020_1, feb_2020_2, feb_2020_3, feb_2020_4, feb_2020_5, feb_2020_6])
feb_2020

# %% [markdown]
# PM10 values of Mar 2020

# %%
start_time = datetime.datetime(2020,3,1,0)
end_time = datetime.datetime(2020,3,6)
mar_20_fun = func(start_time, end_time)
mar_20_fun

# %%
mar_20_1 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',mar_20_fun)
mar_20_1

# %%
mar_2020_1 = pd.read_csv(io.StringIO(mar_20_1.text) )
mar_2020_1 = mar_2020_1[['Variable','Timestamp','Value','Location (WKT)']]
mar_2020_1

# %%
start_time = datetime.datetime(2020,3,6,0)
end_time = datetime.datetime(2020,3,11)
mar_20_fun = func(start_time, end_time)
mar_20_fun

# %%
mar_20_2 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',mar_20_fun)
mar_20_2

# %%
mar_2020_2 = pd.read_csv(io.StringIO(mar_20_2.text) )
mar_2020_2 = mar_2020_2[['Variable','Timestamp','Value','Location (WKT)']]
mar_2020_2

# %%
start_time = datetime.datetime(2020,3,11,0)
end_time = datetime.datetime(2020,3,16)
mar_20_fun = func(start_time, end_time)
mar_20_fun

# %%
mar_20_3 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',mar_20_fun)
mar_20_3

# %%
mar_2020_3 = pd.read_csv(io.StringIO(mar_20_3.text) )
mar_2020_3 = mar_2020_3[['Variable','Timestamp','Value','Location (WKT)']]
mar_2020_3

# %%
start_time = datetime.datetime(2020,3,16,0)
end_time = datetime.datetime(2020,3,21)
mar_20_fun = func(start_time, end_time)
mar_20_fun

# %%
mar_20_4 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',mar_20_fun)
mar_20_4

# %%
mar_2020_4 = pd.read_csv(io.StringIO(mar_20_4.text) )
mar_2020_4 = mar_2020_4[['Variable','Timestamp','Value','Location (WKT)']]
mar_2020_4

# %%
start_time = datetime.datetime(2020,3,21,0)
end_time = datetime.datetime(2020,3,26)
mar_20_fun = func(start_time, end_time)
mar_20_fun

# %%
mar_20_5 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',mar_20_fun)
mar_20_5

# %%
mar_2020_5 = pd.read_csv(io.StringIO(mar_20_5.text) )
mar_2020_5 = mar_2020_5[['Variable','Timestamp','Value','Location (WKT)']]
mar_2020_5

# %%
start_time = datetime.datetime(2020,3,26,0)
end_time = datetime.datetime(2020,4,1)
mar_20_fun = func(start_time, end_time)
mar_20_fun

# %%
mar_20_6 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',mar_20_fun)
mar_20_6

# %%
mar_2020_6 = pd.read_csv(io.StringIO(mar_20_6.text) )
mar_2020_6 = mar_2020_6[['Variable','Timestamp','Value','Location (WKT)']]
mar_2020_6

# %%
mar_2020 = pd.concat([mar_2020_1, mar_2020_2, mar_2020_3, mar_2020_4, mar_2020_5, mar_2020_6])
mar_2020

# %% [markdown]
# PM10 values of Apr 2020

# %%
start_time = datetime.datetime(2020,4,1,0)
end_time = datetime.datetime(2020,4,6)
apr_20_fun = func(start_time, end_time)
apr_20_fun

# %%
apr_20_1 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',apr_20_fun)
apr_20_1

# %%
apr_2020_1 = pd.read_csv(io.StringIO(apr_20_1.text) )
apr_2020_1 = apr_2020_1[['Variable','Timestamp','Value','Location (WKT)']]
apr_2020_1

# %%
start_time = datetime.datetime(2020,4,6,0)
end_time = datetime.datetime(2020,4,11)
apr_20_fun = func(start_time, end_time)
apr_20_fun

# %%
apr_20_2 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',apr_20_fun)
apr_20_2

# %%
apr_2020_2 = pd.read_csv(io.StringIO(apr_20_2.text) )
apr_2020_2 = apr_2020_2[['Variable','Timestamp','Value','Location (WKT)']]
apr_2020_2

# %%
start_time = datetime.datetime(2020,4,11,0)
end_time = datetime.datetime(2020,4,16)
apr_20_fun = func(start_time, end_time)
apr_20_fun

# %%
apr_20_3 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',apr_20_fun)
apr_20_3

# %%
apr_2020_3 = pd.read_csv(io.StringIO(apr_20_3.text) )
apr_2020_3 = apr_2020_3[['Variable','Timestamp','Value','Location (WKT)']]
apr_2020_3

# %%
start_time = datetime.datetime(2020,4,16,0)
end_time = datetime.datetime(2020,4,21)
apr_20_fun = func(start_time, end_time)
apr_20_fun

# %%
apr_20_4 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',apr_20_fun)
apr_20_4

# %%
apr_2020_4 = pd.read_csv(io.StringIO(apr_20_4.text) )
apr_2020_4 = apr_2020_4[['Variable','Timestamp','Value','Location (WKT)']]
apr_2020_4

# %%
start_time = datetime.datetime(2020,4,21,0)
end_time = datetime.datetime(2020,4,26)
apr_20_fun = func(start_time, end_time)
apr_20_fun

# %%
apr_20_5 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',apr_20_fun)
apr_20_5

# %%
apr_2020_5 = pd.read_csv(io.StringIO(apr_20_5.text) )
apr_2020_5 = apr_2020_5[['Variable','Timestamp','Value','Location (WKT)']]
apr_2020_5

# %%
start_time = datetime.datetime(2020,4,26,0)
end_time = datetime.datetime(2020,5,1)
apr_20_fun = func(start_time, end_time)
apr_20_fun

# %%
apr_20_6 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',apr_20_fun)
apr_20_6

# %%
apr_2020_6 = pd.read_csv(io.StringIO(apr_20_6.text) )
apr_2020_6 = apr_2020_6[['Variable','Timestamp','Value','Location (WKT)']]
apr_2020_6

# %%
apr_2020 = pd.concat([apr_2020_1, apr_2020_2, apr_2020_3, apr_2020_4, apr_2020_5, apr_2020_6])
apr_2020

# %% [markdown]
# PM10 values of May 2020

# %%
start_time = datetime.datetime(2020,5,1,0)
end_time = datetime.datetime(2020,5,6)
may_20_fun = func(start_time, end_time)
may_20_fun

# %%
may_20_1 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',may_20_fun)
may_20_1

# %%
may_2020_1 = pd.read_csv(io.StringIO(may_20_1.text) )
may_2020_1 = may_2020_1[['Variable','Timestamp','Value','Location (WKT)']]
may_2020_1

# %%
start_time = datetime.datetime(2020,5,6,0)
end_time = datetime.datetime(2020,5,11)
may_20_fun = func(start_time, end_time)
may_20_fun

# %%
may_20_2 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',may_20_fun)
may_20_2

# %%
may_2020_2 = pd.read_csv(io.StringIO(may_20_2.text) )
may_2020_2 = may_2020_2[['Variable','Timestamp','Value','Location (WKT)']]
may_2020_2

# %%
start_time = datetime.datetime(2020,5,11,0)
end_time = datetime.datetime(2020,5,16)
may_20_fun = func(start_time, end_time)
may_20_fun

# %%
may_20_3 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',may_20_fun)
may_20_3

# %%
may_2020_3 = pd.read_csv(io.StringIO(may_20_3.text) )
may_2020_3 = may_2020_3[['Variable','Timestamp','Value','Location (WKT)']]
may_2020_3

# %%
start_time = datetime.datetime(2020,5,16,0)
end_time = datetime.datetime(2020,5,21)
may_20_fun = func(start_time, end_time)
may_20_fun

# %%
may_20_4 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',may_20_fun)
may_20_4

# %%
may_2020_4 = pd.read_csv(io.StringIO(may_20_4.text) )
may_2020_4 = may_2020_4[['Variable','Timestamp','Value','Location (WKT)']]
may_2020_4

# %%
start_time = datetime.datetime(2020,5,21,0)
end_time = datetime.datetime(2020,5,26)
may_20_fun = func(start_time, end_time)
may_20_fun

# %%
may_20_5 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',may_20_fun)
may_20_5

# %%
may_2020_5 = pd.read_csv(io.StringIO(may_20_5.text) )
may_2020_5 = may_2020_5[['Variable','Timestamp','Value','Location (WKT)']]
may_2020_5

# %%
start_time = datetime.datetime(2020,5,26,0)
end_time = datetime.datetime(2020,6,1)
may_20_fun = func(start_time, end_time)
may_20_fun

# %%
may_20_6 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',may_20_fun)
may_20_6

# %%
may_2020_6 = pd.read_csv(io.StringIO(may_20_6.text) )
may_2020_6 = may_2020_6[['Variable','Timestamp','Value','Location (WKT)']]
may_2020_6

# %%
may_2020 = pd.concat([may_2020_1, may_2020_2, may_2020_3, may_2020_4, may_2020_5, may_2020_6])
may_2020

# %% [markdown]
# PM10 values of June 2020

# %%
start_time = datetime.datetime(2020,6,1,0)
end_time = datetime.datetime(2020,6,6)
jun_20_fun = func(start_time, end_time)
jun_20_fun

# %%
jun_20_1 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',jun_20_fun)
jun_20_1

# %%
jun_2020_1 = pd.read_csv(io.StringIO(jun_20_1.text) )
jun_2020_1 = jun_2020_1[['Variable','Timestamp','Value','Location (WKT)']]
jun_2020_1

# %%
start_time = datetime.datetime(2020,6,6,0)
end_time = datetime.datetime(2020,6,11)
jun_20_fun = func(start_time, end_time)
jun_20_fun

# %%
jun_20_2 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',jun_20_fun)
jun_20_2

# %%
jun_2020_2 = pd.read_csv(io.StringIO(jun_20_2.text) )
jun_2020_2 = jun_2020_2[['Variable','Timestamp','Value','Location (WKT)']]
jun_2020_2

# %%
start_time = datetime.datetime(2020,6,11,0)
end_time = datetime.datetime(2020,6,16)
jun_20_fun = func(start_time, end_time)
jun_20_fun

# %%
jun_20_3 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',jun_20_fun)
jun_20_3

# %%
jun_2020_3 = pd.read_csv(io.StringIO(jun_20_3.text) )
jun_2020_3 = jun_2020_3[['Variable','Timestamp','Value','Location (WKT)']]
jun_2020_3

# %%
start_time = datetime.datetime(2020,6,16,0)
end_time = datetime.datetime(2020,6,21)
jun_20_fun = func(start_time, end_time)
jun_20_fun

# %%
jun_20_4 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',jun_20_fun)
jun_20_4

# %%
jun_2020_4 = pd.read_csv(io.StringIO(jun_20_4.text) )
jun_2020_4 = jun_2020_4[['Variable','Timestamp','Value','Location (WKT)']]
jun_2020_4

# %%
start_time = datetime.datetime(2020,6,21,0)
end_time = datetime.datetime(2020,6,26)
jun_20_fun = func(start_time, end_time)
jun_20_fun

# %%
jun_20_5 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',jun_20_fun)
jun_20_5

# %%
jun_2020_5 = pd.read_csv(io.StringIO(jun_20_5.text) )
jun_2020_5 = jun_2020_5[['Variable','Timestamp','Value','Location (WKT)']]
jun_2020_5

# %%
start_time = datetime.datetime(2020,6,26,0)
end_time = datetime.datetime(2020,7,1)
jun_20_fun = func(start_time, end_time)
jun_20_fun

# %%
jun_20_6 = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',jun_20_fun)
jun_20_6

# %%
jun_2020_6 = pd.read_csv(io.StringIO(jun_20_6.text) )
jun_2020_6 = jun_2020_6[['Variable','Timestamp','Value','Location (WKT)']]
jun_2020_6

# %%
jun_2020 = pd.concat([jun_2020_1, jun_2020_2, jun_2020_3, jun_2020_4, jun_2020_5, jun_2020_6])
jun_2020

# %%
ncl_pm10 = pd.concat([jul_2019, aug_2019, sep_2019, oct_2019, nov_2019, dec_2019, jan_2020, feb_2020, mar_2020, apr_2020, may_2020, jun_2020])
ncl_pm10

# %%
from google.colab import files
ncl_pm10.to_csv('ncl_pm10.csv', index=False)
files.download('ncl_pm10.csv')
